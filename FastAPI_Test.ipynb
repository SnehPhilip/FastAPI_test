# %% [markdown]
# # Why API?
# ### 1. Separation of Concerns (Frontend vs. Backend)
#
# * In the old days, the server handled everything—the data, the logic, and the HTML design.
# * Because we use an API, you can use the same FastAPI backend to power a website, an iPhone app, and an Android app simultaneously.
#
# ### 2. Security and Data Integrity
#
#     * You never want a user's browser to talk directly to your database. That's like giving a customer the keys to your warehouse.
#     * The API is the Clerk:Only if Validation,Authorisation is perfect does the API talk to the database.
#
# ### 3. Machine-to-Machine Communication
#
#     * APIs aren't just for humans using apps.They allow different services to "talk" to each other automatically.
#     * Example: When you buy something on a website, the website's API sends a POST request to
#     * Stripe’s API to process the credit card. Stripe sends a response back, and the website updates your order status.
#
# ### 4. Scalability and Efficiency
#
#     *  If your website gets millions of hits, you can "scale" just the API.
#     *  You can have 10 servers running your FastAPI code and 1 database * server. Because the API uses standard JSON,
#     *  it is incredibly lightweight and fast to transmit over the internet compared to sending entire web pages.

# %%
#### To get started, you need to install FastAPI and Uvicorn, which acts as the lightning-fast ASGI server to run your application.
#### Check python --version   (Python 3.10 or higher reqd)

# %%
pip install fastapi uvicorn
# Out:
# Collecting fastapi
#   Downloading fastapi-0.135.1-py3-none-any.whl.metadata (30 kB)
# Collecting uvicorn
#   Downloading uvicorn-0.41.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting starlette>=0.46.0 (from fastapi)
#   Downloading starlette-0.52.1-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: pydantic>=2.7.0 in /home/admin1/anaconda3/lib/python3.12/site-packages (from fastapi) (2.8.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/admin1/anaconda3/lib/python3.12/site-packages (from fastapi) (4.15.0)
# Collecting typing-inspection>=0.4.2 (from fastapi)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/admin1/anaconda3/lib/python3.12/site-packages (from fastapi) (0.0.4)
# Requirement already satisfied: click>=7.0 in /home/admin1/anaconda3/lib/python3.12/site-packages (from uvicorn) (8.3.1)
# Requirement already satisfied: h11>=0.8 in /home/admin1/anaconda3/lib/python3.12/site-packages (from uvicorn) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/admin1/anaconda3/lib/python3.12/site-packages (from pydantic>=2.7.0->fastapi) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /home/admin1/anaconda3/lib/python3.12/site-packages (from pydantic>=2.7.0->fastapi) (2.20.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in /home/admin1/anaconda3/lib/python3.12/site-packages (from starlette>=0.46.0->fastapi) (4.2.0)
# Requirement already satisfied: idna>=2.8 in /home/admin1/anaconda3/lib/python3.12/site-packages (from anyio<5,>=3.6.2->starlette>=0.46.0->fastapi) (3.7)
# Requirement already satisfied: sniffio>=1.1 in /home/admin1/anaconda3/lib/python3.12/site-packages (from anyio<5,>=3.6.2->starlette>=0.46.0->fastapi) (1.3.0)
# Downloading fastapi-0.135.1-py3-none-any.whl (116 kB)
# Downloading uvicorn-0.41.0-py3-none-any.whl (68 kB)
# Downloading starlette-0.52.1-py3-none-any.whl (74 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Installing collected packages: uvicorn, typing-inspection, starlette, fastapi
# Successfully installed fastapi-0.135.1 starlette-0.52.1 typing-inspection-0.4.2 uvicorn-0.41.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# * Readmore
# * # Test fastapi code in main.py
